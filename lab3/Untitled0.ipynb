# %%
import pandas as pd
import numpy as np

# %%
pd.read_csv('faa-wildlife-strike-clean.csv').head()
# Out:
#    SKY  FLT            DAMAGE REPORTED_NAME REMAINS_COLLECTED BIRDS_SEEN  \
# 0  NaN  NaN               NaN           NaN              True        NaN
# 1  NaN  NaN  Minor (Civilian)           NaN             False        NaN
# 2  NaN  NaN               NaN           NaN              True        NaN
# 3  NaN  NaN   None (Military)       Deleted             False          1
# 4  NaN  NaN   None (Military)       Deleted              True          1
#
#   FAAREGION REPORTED_DATE EFFECT_OTHER REMAINS_SENT  ...   \
# 0       AWP           NaN          NaN        False  ...
# 1       ASO           NaN          NaN        False  ...
# 2       AWP           NaN          NaN        False  ...
# 3       ASO       5/19/00          NaN        False  ...
# 4       ASO       5/19/00          NaN         True  ...
#
#   COST_REPAIRS_INFL_ADJ ENROUTE RUNWAY  \
# 0                   NaN     NaN    NaN
# 1                   NaN     NaN    NaN
# 2                   NaN     NaN    NaN
# 3                   NaN     NaN    NaN
# 4                   NaN     NaN    NaN
#
#                                   AIRPORT  \
# 0                              LIHUE ARPT
# 1  CINCINNATI/NORTHERN KENTUCKY INTL ARPT
# 2                              LIHUE ARPT
# 3                       MYRTLE BEACH INTL
# 4                       JACKSONVILLE INTL
#
#                                        COMMENTS COST_OTHER_INFL_ADJ  \
# 0                                           NaN                 NaN
# 1  SOURCE = FAA AIRCRAFT ACCIDENT/INCIDENT REPT                 NaN
# 2                                           NaN                 NaN
# 3                        SOURCE = BASH NR xxxxx                 NaN
# 4                        SOURCE = BASH NR xxxxx                 NaN
#
#                                              REMARKS NUM_ENGS   TIME SPEED
# 0                                                NaN        2    NaN   NaN
# 1  HIT GULL AFTER T/O (ASSUME CLIMB). CONTD TO DE...        2    NaN   NaN
# 2                                                NaN      NaN    NaN   NaN
# 3  REMARKS -  ;  AIRCRAFT -  A - 10 - ;  IMPACT -...      NaN  09:10   138
# 4  REMARKS -  ;  AIRCRAFT -  F - 16 - ;  IMPACT -...      NaN  09:40   200
#
# [5 rows x 42 columns]

# %%
df = pd.read_csv('faa-wildlife-strike-clean.csv')

# %%
df.COST_OTHER_INFL_ADJ.apply(lambda x: np.float(x))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-84a28d0983ff> in <module>()
# ----> 1 df.COST_OTHER_INFL_ADJ.apply(lambda x: np.float(x))
#
# /Library/Python/2.7/site-packages/pandas/core/series.pyc in apply(self, func, convert_dtype, args, **kwds)
#    2049             values = lib.map_infer(values, lib.Timestamp)
#    2050
# -> 2051         mapped = lib.map_infer(values, f, convert=convert_dtype)
#    2052         if len(mapped) and isinstance(mapped[0], Series):
#    2053             from pandas.core.frame import DataFrame
#
# /Library/Python/2.7/site-packages/pandas/lib.so in pandas.lib.map_infer (pandas/lib.c:56671)()
#
# <ipython-input-8-84a28d0983ff> in <lambda>(x)
# ----> 1 df.COST_OTHER_INFL_ADJ.apply(lambda x: np.float(x))
#
# ValueError: invalid literal for float(): 753,021

# %%
df.groupby(')
